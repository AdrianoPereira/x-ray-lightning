# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
from shapely.ops import transform
from functools import partial
import pyproj
import cartopy.crs as ccrs
import rtree as rt
import seaborn as sns

# %%
P1 = Point(-46.727823, -23.483424)
P2 = Point(-46.727676, -23.483632)
PM = Point((P1.x+P2.x)/2, (P1.y+P2.y)/2)

# %%
def calc_haversine_distance(point1, point2, earth_radius=6373.0):
    lon1, lat1 = point1.x, point1.y
    lon2, lat2 = point2.x, point2.y
    
    rlat1 = np.radians(lat1)
    rlat2 = np.radians(lat2)

    rlon1 = np.radians(lon1)
    rlon2 = np.radians(lon2)

    dlon = rlon2-rlon1
    dlat = rlat2-rlat1

    a = np.sin(dlat / 2)**2 + np.cos(rlat1) * np.cos(rlat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    return earth_radius * c


def calc_azimuth_angle(point1, point2):
    lon1, lat1 = point1.x, point1.y
    lon2, lat2 = point2.x, point2.y
    
    lat1 = np.radians(lat1)
    lat2 = np.radians(lat2)

    dl = np.radians(lon2 - lon1)

    x = np.sin(dl)*np.cos(lat2)
    y = np.cos(lat1)*np.sin(lat2) - (np.sin(lat1)*np.cos(lat2)*np.cos(dl))

    initial_bearing = np.degrees(np.arctan2(x, y))
    compass_bearing = (initial_bearing + 360) % 360

    return compass_bearing


def calc_buffer_area_from_point(point, km):
    lon, lat = point.x, point.y
    
    proj_wgs84 = pyproj.Proj('+proj=longlat +datum=WGS84')
    aeqd_proj = '+proj=aeqd +lat_0={lat} +lon_0={lon} +x_0=0 +y_0=0'
    project = partial(
        pyproj.transform,
        pyproj.Proj(aeqd_proj.format(lat=lat, lon=lon)),
        proj_wgs84
    )
    buf = Point(0, 0).buffer(km*1000)
    return transform(project, buf).exterior.coords[:]

# %%
fig, ax = plt.subplots(figsize=(7, 7))

ax.set_xlim((-5, 5))
ax.set_ylim((-5, 5))
ax.grid(ls='--')

ref = Point(0, 0)
p1 = Point(0, 2)
p2 = Point(1.5, 1.5)
p3 = Point(2, 0)
p4 = Point(1.5, -1.5)
p5 = Point(0, -2)
p6 = Point(-1.5, -1.5)
p7 = Point(-2, 0)
p8 = Point(-1.5, 1.5)

ap1 = calc_azimuth_angle(ref, p1)
ap2 = calc_azimuth_angle(ref, p2)
ap3 = calc_azimuth_angle(ref, p3)
ap4 = calc_azimuth_angle(ref, p4)
ap5 = calc_azimuth_angle(ref, p5)
ap6 = calc_azimuth_angle(ref, p6)
ap7 = calc_azimuth_angle(ref, p7)
ap8 = calc_azimuth_angle(ref, p8)

ax.scatter(ref.x, ref.y, marker='*', color='k', label='Reference')
ax.scatter(p1.x, p1.y, color='k', label=f'P1 ({ap1:.1f}°)')
ax.scatter(p2.x, p2.y, color='r', label=f'P2 ({ap2:.1f}°)')
ax.scatter(p3.x, p3.y, color='g', label=f'P3 ({ap3:.1f}°)')
ax.scatter(p4.x, p4.y, color='b', label=f'P4 ({ap4:.1f}°)')
ax.scatter(p5.x, p5.y, color='yellow', label=f'P5 ({ap5:.1f}°)')
ax.scatter(p6.x, p6.y, color='purple', label=f'P6 ({ap6:.1f}°)')
ax.scatter(p7.x, p7.y, color='orange', label=f'P7 ({ap7:.1f}°)')
ax.scatter(p8.x, p8.y, color='brown', label=f'P8 ({ap8:.1f}°)')

ax.legend(ncol=3, loc='upper center')

# %%
sp_mesh = gpd.read_file("../data/shapefiles/sao_paulo_municipal_mesh.shp")
sp_mesh.head()
# Out:
#     CD_MUN            NM_MUN SIGLA_UF  AREA_KM2  \
# 0  3500105        Adamantina       SP   411.987
# 1  3500204            Adolfo       SP   211.055
# 2  3500303             Aguaí       SP   474.554
# 3  3500402    Águas da Prata       SP   142.673
# 4  3500501  Águas de Lindóia       SP    60.126
#
#                                             geometry
# 0  POLYGON ((-51.05425 -21.40465, -51.05300 -21.4...
# 1  POLYGON ((-49.65795 -21.20333, -49.65645 -21.2...
# 2  POLYGON ((-46.97640 -21.96818, -46.97599 -21.9...
# 3  POLYGON ((-46.73501 -21.81891, -46.73431 -21.8...
# 4  POLYGON ((-46.60614 -22.44173, -46.60347 -22.4...

# %%
buffer_area = calc_buffer_area_from_point(P2, 7)
circle_area = Polygon(list((x, y) for x, y in buffer_area))

margin = 0.01
bounds = circle_area.bounds
bounds = (bounds[0]-margin, bounds[2]+margin, bounds[1]-margin, bounds[3]+margin)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_geometries(sp_mesh.geometry, ccrs.PlateCarree(), zorder=1, fc='#f9f9f9', ec='k', lw=1)
ax.set_extent(bounds, ccrs.PlateCarree())

ax.gridlines(draw_labels=True, linestyle='--')

ax.scatter([P2.x], [P2.y], c='red', s=100, marker='^', zorder=2, label='P2')
ax.plot(*circle_area.exterior.xy, c='green', label='Radius 7km')

ax.legend(loc='lower right')

# %%
brasildat_df = pd.read_csv("./data/lightning_sensors/brasildat/brasildat_20190124.txt", sep=';')
brasildat_df = gpd.GeoDataFrame(
    brasildat_df, geometry=gpd.points_from_xy(x=brasildat_df.dat_longitude, y=brasildat_df.dat_latitude)
).drop(['dat_longitude', 'dat_latitude'], axis=1)
brasildat_df['data'] = pd.to_datetime(brasildat_df['data'], format='%Y-%m-%d %H:%M:%S')

brasildat_df.head()
# Out:
#                  data  dat_nanosegundo  dat_corrente_pico_ka  \
# 0 2019-01-24 15:00:00        115125712                     4
# 1 2019-01-24 15:00:00        116275000                     3
# 2 2019-01-24 15:00:00        122225024                     2
# 3 2019-01-24 15:00:00        123300048                     7
# 4 2019-01-24 15:00:00        127194664                     8
#
#    dat_semieixo_maior  dat_azimute_elipse  dat_flag_intranuvem  \
# 0                 0.6                  81                    1
# 1                 0.6                 144                    1
# 2                 0.6                  58                    1
# 3                 0.5                 160                    1
# 4                 0.7                   5                    1
#
#                       geometry
# 0  POINT (-60.19370 -33.69750)
# 1  POINT (-60.20240 -33.70790)
# 2  POINT (-60.19860 -33.69940)
# 3  POINT (-60.19580 -33.69520)
# 4  POINT (-60.17450 -33.68660)

# %%
rtree = rt.index.Index()
for i, row in brasildat_df.iterrows():
    rtree.insert(i, Point(row.dat_longitude, row.dat_latitude).bounds)

# %%
sindex_matches = list(rtree.intersection(circle_area.bounds))
points_matches = brasildat_df.iloc[sindex_matches]
brasildat_df = points_matches[points_matches.intersects(circle_area)]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10), subplot_kw={'projection': ccrs.PlateCarree()})
ax.add_geometries(sp_mesh.geometry, ccrs.PlateCarree(), zorder=1, fc='#f9f9f9', ec='k', lw=1)
ax.set_extent(bounds, ccrs.PlateCarree())

ax.gridlines(draw_labels=True, linestyle='--')

ax.scatter([P2.x], [P2.y], c='red', s=100, marker='^', zorder=2, label='P2')
ax.plot(*circle_area.exterior.xy, c='green', label='Radius 7km')
brasildat_df.plot(ax=ax, c='b', marker='x', zorder=2, label='Brasildat lightnings')

ax.legend(loc='lower right')

# %%
brasildat_df['distance_km'] = brasildat_df.apply(
    lambda row: calc_haversine_distance(P2, row['geometry']),
    axis=1
)

brasildat_df['azimuth_angle'] = brasildat_df.apply(
    lambda row: calc_azimuth_angle(P2, row['geometry']),
    axis=1
)
# Out:
# /home/adriano/anaconda3/envs/vpn/lib/python3.7/site-packages/geopandas/geodataframe.py:1259: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
plt.hist(brasildat_df['azimuth_angle'].values)
# Out:
# (array([ 54.,  36.,  43.,  54.,  35.,  33.,  44., 119., 154.,  64.]),
#  array([  0.49715502,  36.00369305,  71.51023109, 107.01676913,
#         142.52330716, 178.0298452 , 213.53638323, 249.04292127,
#         284.5494593 , 320.05599734, 355.56253538]),
#  <BarContainer object of 10 artists>)
